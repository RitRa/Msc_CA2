# %% [markdown]
# First, to get acess to the tweets, you need to setup a developer account with Twitter at https://developer.twitter.com/en/portal/products/elevated
#
# This will give you the api key, api key secret, access token and access token secret to gain access to the tweets. To get elevated access to twitter you need to expalin what you are doing with the tweets. gives you acess to 2M Tweets per month / Project.
#
# To get all the tweets we will use a python library called Tweepy, using pip install tweepy. https://docs.tweepy.org/en/latest/getting_started.html#hello-tweepy
#
#
# OPen twitter api in postman, to view the collection
# https://www.postman.com/twitter/workspace/twitter-s-public-workspace/collection/9956214-784efcda-ed4c-4491-a4c0-a26470a67400?ctx=documentation

# %% [markdown]
# tutorials - https://www.youtube.com/watch?v=Lu1nskBkPJU
#
# https://www.youtube.com/watch?v=kgNNhjTGLN0
#
# https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/twitter-data-in-python/

# %%
# library 
#!pip install tweepy

# %%
import tweepy as tw
consumer_key = "wMdUP2fc4d6gqTO8qH41IeRrY"
consumer_secret = "jCuvCMrT9FkPSyC1uhULfW8OYYnjqyl8RgcTLbI2ZNNnRugzIi"
access_token = "1316278477-pItksAj8B9db1uGZmIu1jaINhP5f1Jl6TRc0vNM"
access_token_secret = "MDDB6LsUHWr2ig46UGPGbNzqGMvGaD8Id1oUT8sVbowvY"
bearer_token = "AAAAAAAAAAAAAAAAAAAAACxWbwEAAAAAjouhYAFZU%2F7F3oR77ehZpoJW%2BWA%3DXO8JMqLbPBYSguAjwxseQ12y2xD8UBZVFN1tp3eawiRiLBY2sM"

# %%
auth = tw.OAuth1UserHandler(
   consumer_key, consumer_secret, access_token, access_token_secret
)

api = tw.API(auth, wait_on_rate_limit=True)

#public_tweets = api.home_timeline()
#for tweet in public_tweets:
#    print(tweet.text)

# %% [markdown]
# https://towardsdatascience.com/searching-for-tweets-with-python-f659144b225f

# %%
import requests
import json
import pprint
#its bad practice to place your bearer token directly into the script (this is just done for illustration purposes)
BEARER_TOKEN = bearer_token
#define search twitter function
def search_twitter(query, tweet_fields, bearer_token = BEARER_TOKEN):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}

    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}".format(
        query, tweet_fields
    )
    response = requests.request("GET", url, headers=headers)

    print(response.status_code)

    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#search term
query = "fertiliser price"

#"country": "United States"

country = "Ireland"

#"country": "United States"
#twitter fields to be returned by api call
tweet_fields = "tweet.fields=text,author_id,created_at"

place_fields = "place.fields=country"

#twitter api call
json_response = search_twitter(query=query, tweet_fields=tweet_fields , bearer_token=BEARER_TOKEN)


#pretty printing
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "914994564397764610",
#             "created_at": "2022-04-24T17:11:59.000Z",
#             "id": "1518276578140119046",
#             "text": "Fertiliser and animal feed cost has gone through the roof. In certain cases, like urea, the price has quintupled with very prolonged lead times. They are systematically driving up the cost of staple crops - wheat, corn, soybean, potatoes. It's completely engineered. If Ukraine is"
#         },
#         {
#             "author_id": "225539566",
#             "created_at": "2022-04-24T17:07:17.000Z",
#             "id": "1518275398081163265",
#             "text": "RT @RachelSweeneyNE: FARMING: Dairy farmers say the industry is 'on its knees' because of tripled fertiliser prices. In Jan, I reported pre\u2026"
#         },
#         {
#             "author_id": "267829268",
#             "created_at": "2022-04-24T17:01:00.000Z",
#             "id": "1518273815129649152",
#             "text": "FARMING: Dairy farmers say the industry is 'on its knees' because of tripled fertiliser prices. In Jan, I reported predicted milk shortages/price hikes. With energy, petrol &amp; supply costs rising, the situation is far from over. @GBNews tomorrow @EamonnHolmes @IsabelWebster_ https://t.co/2nHYH424Qc"
#         },
#         {
#             "author_id": "253168180",
#             "created_at": "2022-04-24T16:45:25.000Z",
#             "id": "1518269896072773632",
#             "text": "RT @toluogunlesi: #PFInigeria is managed and overseen by @nsia_nigeria, on behalf of @NigeriaGov.\n\nNSIA CEO has an interview in @BusinessDa\u2026"
#         },
#         {
#             "author_id": "127681213",
#             "created_at": "2022-04-24T16:34:38.000Z",
#             "id": "1518267181825462276",
#             "text": "RT @toluogunlesi: #PFInigeria is managed and overseen by @nsia_nigeria, on behalf of @NigeriaGov.\n\nNSIA CEO has an interview in @BusinessDa\u2026"
#         },
#         {
#             "author_id": "23584333",
#             "created_at": "2022-04-24T16:25:48.000Z",
#             "id": "1518264955874820097",
#             "text": "#PFInigeria is managed and overseen by @nsia_nigeria, on behalf of @NigeriaGov.\n\nNSIA CEO has an interview in @BusinessDayNg, that sheds light on #PFInigeria\u2019s successes, and the current fertilizer pricing challenges, (caused primarily by gas price surge): https://t.co/HMn73n1l8C"
#         },
#         {
#             "author_id": "1907346698",
#             "created_at": "2022-04-24T15:27:34.000Z",
#             "id": "1518250304407588864",
#             "text": "RT @toluogunlesi: @JamiluHaruna \u201cUnless you\u2019ve been living under a rock,you\u2019ll know that natural gas is a big problem.\u00a0A couple of\u00a0Fertiliz\u2026"
#         },
#         {
#             "author_id": "1265792200731955206",
#             "created_at": "2022-04-24T14:50:22.000Z",
#             "id": "1518240939176771584",
#             "text": "RT @JamesMelville: \u25aa\ufe0fRed diesel (used in farm machinery) has doubled in price \n\u25aa\ufe0fFarmers are being forced to ration on red diesel \n\u25aa\ufe0fFertil\u2026"
#         },
#         {
#             "author_id": "1340829412393152512",
#             "created_at": "2022-04-24T11:43:23.000Z",
#             "id": "1518193886342135808",
#             "text": "@CahairOKane1 Welcome to Donegal, with the price of fertiliser lucky to have any grass \nBallybofey a huge pitch anyways so a yard here or there means nothing!!"
#         },
#         {
#             "author_id": "177969472",
#             "created_at": "2022-04-24T10:07:38.000Z",
#             "id": "1518169789281226752",
#             "text": "@Serendipity_03_ @Tylwyth_Tegi @Jo521969 2)\u2026a talk. He already did quite a bit of organic farming. Many farmers are increasing non or reduced fertilised crops but most had already bought this years fertiliser before price hike. Some fields that had to be fallow under EU Rules brought back into use\n\nThe biggest hits \u20263"
#         }
#     ],
#     "meta": {
#         "newest_id": "1518276578140119046",
#         "next_token": "b26v89c19zqg8o3fpytodtbur5dcfugit987nzrd2fp19",
#         "oldest_id": "1518169789281226752",
#         "result_count": 10
#     }
# }

# %%
pprint.pprint(json_response['data'])
# Out:
# [{'author_id': '914994564397764610',
#   'created_at': '2022-04-24T17:11:59.000Z',
#   'id': '1518276578140119046',
#   'text': 'Fertiliser and animal feed cost has gone through the roof. In '
#           'certain cases, like urea, the price has quintupled with very '
#           'prolonged lead times. They are systematically driving up the cost '
#           "of staple crops - wheat, corn, soybean, potatoes. It's completely "
#           'engineered. If Ukraine is'},
#  {'author_id': '225539566',
#   'created_at': '2022-04-24T17:07:17.000Z',
#   'id': '1518275398081163265',
#   'text': "RT @RachelSweeneyNE: FARMING: Dairy farmers say the industry is 'on "
#           "its knees' because of tripled fertiliser prices. In Jan, I reported "
#           'pre…'},
#  {'author_id': '267829268',
#   'created_at': '2022-04-24T17:01:00.000Z',
#   'id': '1518273815129649152',
#   'text': "FARMING: Dairy farmers say the industry is 'on its knees' because "
#           'of tripled fertiliser prices. In Jan, I reported predicted milk '
#           'shortages/price hikes. With energy, petrol &amp; supply costs '
#           'rising, the situation is far from over. @GBNews tomorrow '
#           '@EamonnHolmes @IsabelWebster_ https://t.co/2nHYH424Qc'},
#  {'author_id': '253168180',
#   'created_at': '2022-04-24T16:45:25.000Z',
#   'id': '1518269896072773632',
#   'text': 'RT @toluogunlesi: #PFInigeria is managed and overseen by '
#           '@nsia_nigeria, on behalf of @NigeriaGov.\n'
#           '\n'
#           'NSIA CEO has an interview in @BusinessDa…'},
#  {'author_id': '127681213',
#   'created_at': '2022-04-24T16:34:38.000Z',
#   'id': '1518267181825462276',
#   'text': 'RT @toluogunlesi: #PFInigeria is managed and overseen by '
#           '@nsia_nigeria, on behalf of @NigeriaGov.\n'
#           '\n'
#           'NSIA CEO has an interview in @BusinessDa…'},
#  {'author_id': '23584333',
#   'created_at': '2022-04-24T16:25:48.000Z',
#   'id': '1518264955874820097',
#   'text': '#PFInigeria is managed and overseen by @nsia_nigeria, on behalf of '
#           '@NigeriaGov.\n'
#           '\n'
#           'NSIA CEO has an interview in @BusinessDayNg, that sheds light on '
#           '#PFInigeria’s successes, and the current fertilizer pricing '
#           'challenges, (caused primarily by gas price surge): '
#           'https://t.co/HMn73n1l8C'},
#  {'author_id': '1907346698',
#   'created_at': '2022-04-24T15:27:34.000Z',
#   'id': '1518250304407588864',
#   'text': 'RT @toluogunlesi: @JamiluHaruna “Unless you’ve been living under a '
#           'rock,you’ll know that natural gas is a big problem.\xa0A couple '
#           'of\xa0Fertiliz…'},
#  {'author_id': '1265792200731955206',
#   'created_at': '2022-04-24T14:50:22.000Z',
#   'id': '1518240939176771584',
#   'text': 'RT @JamesMelville: ▪️Red diesel (used in farm machinery) has '
#           'doubled in price \n'
#           '▪️Farmers are being forced to ration on red diesel \n'
#           '▪️Fertil…'},
#  {'author_id': '1340829412393152512',
#   'created_at': '2022-04-24T11:43:23.000Z',
#   'id': '1518193886342135808',
#   'text': '@CahairOKane1 Welcome to Donegal, with the price of fertiliser '
#           'lucky to have any grass \n'
#           'Ballybofey a huge pitch anyways so a yard here or there means '
#           'nothing!!'},
#  {'author_id': '177969472',
#   'created_at': '2022-04-24T10:07:38.000Z',
#   'id': '1518169789281226752',
#   'text': '@Serendipity_03_ @Tylwyth_Tegi @Jo521969 2)…a talk. He already did '
#           'quite a bit of organic farming. Many farmers are increasing non or '
#           'reduced fertilised crops but most had already bought this years '
#           'fertiliser before price hike. Some fields that had to be fallow '
#           'under EU Rules brought back into use\n'
#           '\n'
#           'The biggest hits …3'}]

# %%
pretty_print_json = pprint.pformat(json_response['data']).replace("'", '"')
pretty_print_json
# Out:
# '[{"author_id": "914994564397764610",\n  "created_at": "2022-04-24T17:11:59.000Z",\n  "id": "1518276578140119046",\n  "text": "Fertiliser and animal feed cost has gone through the roof. In "\n          "certain cases, like urea, the price has quintupled with very "\n          "prolonged lead times. They are systematically driving up the cost "\n          "of staple crops - wheat, corn, soybean, potatoes. It"s completely "\n          "engineered. If Ukraine is"},\n {"author_id": "225539566",\n  "created_at": "2022-04-24T17:07:17.000Z",\n  "id": "1518275398081163265",\n  "text": "RT @RachelSweeneyNE: FARMING: Dairy farmers say the industry is "on "\n          "its knees" because of tripled fertiliser prices. In Jan, I reported "\n          "pre…"},\n {"author_id": "267829268",\n  "created_at": "2022-04-24T17:01:00.000Z",\n  "id": "1518273815129649152",\n  "text": "FARMING: Dairy farmers say the industry is "on its knees" because "\n          "of tripled fertiliser prices. In Jan, I reported predicted milk "\n          "shortages/price hikes. With energy, petrol &amp; supply costs "\n          "rising, the situation is far from over. @GBNews tomorrow "\n          "@EamonnHolmes @IsabelWebster_ https://t.co/2nHYH424Qc"},\n {"author_id": "253168180",\n  "created_at": "2022-04-24T16:45:25.000Z",\n  "id": "1518269896072773632",\n  "text": "RT @toluogunlesi: #PFInigeria is managed and overseen by "\n          "@nsia_nigeria, on behalf of @NigeriaGov.\\n"\n          "\\n"\n          "NSIA CEO has an interview in @BusinessDa…"},\n {"author_id": "127681213",\n  "created_at": "2022-04-24T16:34:38.000Z",\n  "id": "1518267181825462276",\n  "text": "RT @toluogunlesi: #PFInigeria is managed and overseen by "\n          "@nsia_nigeria, on behalf of @NigeriaGov.\\n"\n          "\\n"\n          "NSIA CEO has an interview in @BusinessDa…"},\n {"author_id": "23584333",\n  "created_at": "2022-04-24T16:25:48.000Z",\n  "id": "1518264955874820097",\n  "text": "#PFInigeria is managed and overseen by @nsia_nigeria, on behalf of "\n          "@NigeriaGov.\\n"\n          "\\n"\n          "NSIA CEO has an interview in @BusinessDayNg, that sheds light on "\n          "#PFInigeria’s successes, and the current fertilizer pricing "\n          "challenges, (caused primarily by gas price surge): "\n          "https://t.co/HMn73n1l8C"},\n {"author_id": "1907346698",\n  "created_at": "2022-04-24T15:27:34.000Z",\n  "id": "1518250304407588864",\n  "text": "RT @toluogunlesi: @JamiluHaruna “Unless you’ve been living under a "\n          "rock,you’ll know that natural gas is a big problem.\\xa0A couple "\n          "of\\xa0Fertiliz…"},\n {"author_id": "1265792200731955206",\n  "created_at": "2022-04-24T14:50:22.000Z",\n  "id": "1518240939176771584",\n  "text": "RT @JamesMelville: ▪️Red diesel (used in farm machinery) has "\n          "doubled in price \\n"\n          "▪️Farmers are being forced to ration on red diesel \\n"\n          "▪️Fertil…"},\n {"author_id": "1340829412393152512",\n  "created_at": "2022-04-24T11:43:23.000Z",\n  "id": "1518193886342135808",\n  "text": "@CahairOKane1 Welcome to Donegal, with the price of fertiliser "\n          "lucky to have any grass \\n"\n          "Ballybofey a huge pitch anyways so a yard here or there means "\n          "nothing!!"},\n {"author_id": "177969472",\n  "created_at": "2022-04-24T10:07:38.000Z",\n  "id": "1518169789281226752",\n  "text": "@Serendipity_03_ @Tylwyth_Tegi @Jo521969 2)…a talk. He already did "\n          "quite a bit of organic farming. Many farmers are increasing non or "\n          "reduced fertilised crops but most had already bought this years "\n          "fertiliser before price hike. Some fields that had to be fallow "\n          "under EU Rules brought back into use\\n"\n          "\\n"\n          "The biggest hits …3"}]'

# %%
with open('file_name.json', 'w') as f:
    f.write(pretty_print_json)

# %%
df = pd.read_json('file_name.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-29bae827b373> in <module>
# ----> 1 df = pd.read_json('file_name.json')
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#     750         return obj
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# ValueError: Unexpected character found when decoding object value

# %%
def make_df(json_response):
    return pd.DataFrame(json_response['data'])

# %%
df =make_df(json_response)

# %%
df
# Out:
#                  created_at  \
# 0  2022-04-24T17:11:59.000Z
# 1  2022-04-24T17:07:17.000Z
# 2  2022-04-24T17:01:00.000Z
# 3  2022-04-24T16:45:25.000Z
# 4  2022-04-24T16:34:38.000Z
# 5  2022-04-24T16:25:48.000Z
# 6  2022-04-24T15:27:34.000Z
# 7  2022-04-24T14:50:22.000Z
# 8  2022-04-24T11:43:23.000Z
# 9  2022-04-24T10:07:38.000Z
#
#                                                 text                   id  \
# 0  Fertiliser and animal feed cost has gone throu...  1518276578140119046
# 1  RT @RachelSweeneyNE: FARMING: Dairy farmers sa...  1518275398081163265
# 2  FARMING: Dairy farmers say the industry is 'on...  1518273815129649152
# 3  RT @toluogunlesi: #PFInigeria is managed and o...  1518269896072773632
# 4  RT @toluogunlesi: #PFInigeria is managed and o...  1518267181825462276
# 5  #PFInigeria is managed and overseen by @nsia_n...  1518264955874820097
# 6  RT @toluogunlesi: @JamiluHaruna “Unless you’ve...  1518250304407588864
# 7  RT @JamesMelville: ▪️Red diesel (used in farm ...  1518240939176771584
# 8  @CahairOKane1 Welcome to Donegal, with the pri...  1518193886342135808
# 9  @Serendipity_03_ @Tylwyth_Tegi @Jo521969 2)…a ...  1518169789281226752
#
#              author_id
# 0   914994564397764610
# 1            225539566
# 2            267829268
# 3            253168180
# 4            127681213
# 5             23584333
# 6           1907346698
# 7  1265792200731955206
# 8  1340829412393152512
# 9            177969472
